# %% [markdown]
# # Multi Table Structure

# %%
metadata.visualize()

# %% [markdown]
# # Table names

# %%
real_data.keys()
# Out:
# dict_keys(['Classification', 'Genes', 'Interactions'])

# %% [markdown]
# # Table Classification

# %%
real_data['Classification'].columns
# Out:
# Index(['GeneID', 'Localization', 'sum(Expression_Corr)',
#        'max(Expression_Corr)', 'min(Expression_Corr)', 'nb_rows_in_Genes',
#        'nb_rows_in_Interactions'],
#       dtype='object')

# %%
real_data['Classification'].head()
# Out:
#     GeneID  Localization  sum(Expression_Corr)  max(Expression_Corr)  \
# 0  G234064     cytoplasm              1.665680              0.914095
# 1  G234065     cytoplasm              1.762775              0.939001
# 2  G234070  cytoskeleton              0.000000              0.000000
# 3  G234073     cytoplasm              3.368688              0.749192
# 4  G234074     cytoplasm              2.089604              0.700202
#
#    min(Expression_Corr)  nb_rows_in_Genes  nb_rows_in_Interactions
# 0              0.751585                 4                      2.0
# 1              0.823774                 8                      2.0
# 2              0.000000                 6                      0.0
# 3              0.358224                 2                      6.0
# 4              0.370059                12                      4.0

# %%
num_cols=['sum(Expression_Corr)','max(Expression_Corr)','min(Expression_Corr)','nb_rows_in_Genes','nb_rows_in_Interactions']
cat_cols=['Localization']

# %% [markdown]
# # Table Genes

# %%
real_data['Genes'].columns
# Out:
# Index(['GeneID', 'Essential', 'Class', 'Complex', 'Phenotype', 'Motif',
#        'Chromosome', 'Function', 'Localization', 'add_numerical'],
#       dtype='object')

# %%
real_data['Genes'].head()
# Out:
#     GeneID      Essential                            Class  \
# 0  G234064      Essential  GTP/GDP-exchange factors (GEFs)
# 1  G234064      Essential  GTP/GDP-exchange factors (GEFs)
# 2  G234064      Essential  GTP/GDP-exchange factors (GEFs)
# 3  G234064      Essential  GTP/GDP-exchange factors (GEFs)
# 4  G234065  Non-Essential                          ATPases
#
#                  Complex Phenotype    Motif  Chromosome  \
# 0  Translation complexes         ?  PS00824           1
# 1  Translation complexes         ?  PS00824           1
# 2  Translation complexes         ?  PS00825           1
# 3  Translation complexes         ?  PS00825           1
# 4                      ?         ?        ?           1
#
#                                             Function Localization  \
# 0  CELLULAR ORGANIZATION (proteins are localized ...    cytoplasm
# 1                                  PROTEIN SYNTHESIS    cytoplasm
# 2  CELLULAR ORGANIZATION (proteins are localized ...    cytoplasm
# ...

# %%
num_cols=['add_numerical','Chromosome']
cat_cols=['Complex','Class','Localization','Phenotype']

# %% [markdown]
# # Table Interactions

# %%
real_data['Interactions'].head()
# Out:
#    GeneID1_GeneID2  GeneID1  GeneID2              Type  Expression_Corr  \
# 0  G234064_G234126  G234064  G234126  Genetic-Physical         0.914095
# 1  G234064_G235065  G234064  G235065  Genetic-Physical         0.751585
# 2  G234065_G234371  G234065  G234371           Genetic         0.823774
# 3  G234065_G234854  G234065  G234854          Physical         0.939001
# 4  G234073_G234065  G234073  G234065          Physical         0.749192
#
#    add_numerical
# 0       0.914095
# 1       0.751585
# 2       0.823774
# 3       0.939001
# 4       0.749192

# %%
num_cols=['Expression_Corr','add_numerical']
cat_cols=['Type']
